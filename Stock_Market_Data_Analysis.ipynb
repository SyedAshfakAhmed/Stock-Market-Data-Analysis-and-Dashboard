# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ### 1. Prerequisites
# Here, we'll discuss using Pandas to handle stock information requests and conduct basic stock analysis.

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf
from pandas_datareader import data as pdr
from datetime import datetime
from datetime import date as dt
yf.pdr_override()

# %%
# Set the start and end date
start_date = '2013-01-01'
end_date = str(dt.today())

# Set the stocks()amazon, chevron, IBM, ares capital, AT&T)

stocks = ['AMZN','CVX','IBM','ARCC','T','MSFT']

for stock in stocks:
    globals()[stock] = yf.download(stock, start_date, end_date)


company_list = [AMZN, CVX, IBM, ARCC, T, MSFT]
company_name = ["Amazon", "Chevron", "IBM", "Ares Capital", "AT&T","MSFT"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data_1 = yf.download('AMZN',start_date, end_date)
data_1.reset_index(inplace = True)
data_1['stock'] = 'Amazon'
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_1
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2013-01-02   12.804000   12.905000   12.663000   12.865500   12.865500
# 1    2013-01-03   12.863500   13.044000   12.818500   12.924000   12.924000
# 2    2013-01-04   12.879000   12.990000   12.832500   12.957500   12.957500
# 3    2013-01-07   13.148500   13.486500   13.133500   13.423000   13.423000
# 4    2013-01-08   13.353500   13.449000   13.178500   13.319000   13.319000
# ...         ...         ...         ...         ...         ...         ...
# 2579 2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 2580 2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 2581 2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 2582 2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
# 2583 2023-04-06  100.750000  102.379997   99.800003  102.059998  102.059998
#
#         Volume   stock
# 0     65420000  Amazon
# ...

# %%
data_2 = yf.download('CVX', start_date, end_date)
data_2.reset_index(inplace = True)
data_2['stock'] = 'Chevron'
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_2
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2013-01-02  110.269997  110.419998  108.739998  110.389999   72.360191
# 1    2013-01-03  110.139999  110.919998  109.510002  109.919998   72.052109
# 2    2013-01-04  109.989998  110.620003  109.900002  110.500000   72.432289
# 3    2013-01-07  110.019997  110.089996  109.190002  109.750000   71.940659
# 4    2013-01-08  109.480003  109.690002  109.099998  109.260002   71.619492
# ...         ...         ...         ...         ...         ...         ...
# 2579 2023-03-31  162.699997  163.720001  162.149994  163.160004  163.160004
# 2580 2023-04-03  169.800003  171.100006  168.919998  169.949997  169.949997
# 2581 2023-04-04  171.139999  171.139999  167.720001  169.039993  169.039993
# 2582 2023-04-05  169.259995  170.440002  167.740005  169.880005  169.880005
# 2583 2023-04-06  169.350006  169.410004  167.130005  167.649994  167.649994
#
#         Volume    stock
# 0      6144100  Chevron
# ...

# %%
data_3 = yf.download('IBM', start_date, end_date)
data_3.reset_index(inplace = True)
data_3['stock'] = 'IBM'
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_3
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2013-01-02  185.554489  187.715103  185.277252  187.715103  125.490417
# 1    2013-01-03  187.065002  187.657745  185.889099  186.682602  124.800201
# 2    2013-01-04  185.650101  185.908218  184.302109  185.458893  123.982132
# 3    2013-01-07  184.894836  185.258133  183.881454  184.646271  123.438911
# 4    2013-01-08  184.435944  184.799240  183.173996  184.388138  123.266312
# ...         ...         ...         ...         ...         ...         ...
# 2579 2023-03-31  129.470001  131.229996  129.419998  131.089996  131.089996
# 2580 2023-04-03  130.970001  132.610001  130.770004  132.059998  132.059998
# 2581 2023-04-04  131.990005  132.149994  130.889999  131.600006  131.600006
# 2582 2023-04-05  131.369995  132.610001  131.369995  132.139999  132.139999
# 2583 2023-04-06  132.160004  132.600006  130.320007  130.500000  130.500000
#
#        Volume stock
# 0     4428869   IBM
# ...

# %%
data_4 = yf.download('ARCC', start_date, end_date)
data_4.reset_index(inplace = True)
data_4['stock'] = 'Ares Capital'
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_4
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2013-01-02  17.750000  17.809999  17.600000  17.730000   6.684817
# 1    2013-01-03  17.680000  17.809999  17.620001  17.799999   6.711205
# 2    2013-01-04  17.840000  17.850000  17.639999  17.840000   6.726288
# 3    2013-01-07  17.830000  17.870001  17.730000  17.780001   6.703667
# 4    2013-01-08  17.820000  17.860001  17.670000  17.770000   6.699898
# ...         ...        ...        ...        ...        ...        ...
# 2579 2023-03-31  18.350000  18.469999  18.200001  18.270000  18.270000
# 2580 2023-04-03  18.270000  18.500000  18.120001  18.299999  18.299999
# 2581 2023-04-04  18.309999  18.350000  17.980000  18.120001  18.120001
# 2582 2023-04-05  18.000000  18.150000  17.850000  17.910000  17.910000
# 2583 2023-04-06  17.959999  18.049999  17.920000  18.040001  18.040001
#
#        Volume         stock
# 0     1388400  Ares Capital
# 1     1188300  Ares Capital
# ...

# %%
data_5 = yf.download('T', start_date, end_date)
data_5.reset_index(inplace = True)
data_5['stock'] = 'AT&T'
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_5
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2013-01-02  25.974319  26.435045  25.838369  26.435045  12.094461
# 1    2013-01-03  26.503021  26.563444  26.261330  26.450151  12.101371
# 2    2013-01-04  26.510574  26.638973  26.435045  26.608761  12.173941
# 3    2013-01-07  26.623867  26.812689  26.510574  26.729607  12.229228
# 4    2013-01-08  26.450151  26.465258  25.883686  25.944109  12.073103
# ...         ...        ...        ...        ...        ...        ...
# 2579 2023-03-31  19.120001  19.250000  19.030001  19.250000  18.980810
# 2580 2023-04-03  19.270000  19.480000  19.200001  19.389999  19.118851
# 2581 2023-04-04  19.520000  19.650000  19.389999  19.639999  19.365356
# 2582 2023-04-05  19.620001  19.930000  19.590000  19.879999  19.601999
# 2583 2023-04-06  19.650000  19.790001  19.510000  19.650000  19.650000
#
#         Volume stock
# 0     50740314  AT&T
# 1     38306895  AT&T
# 2     27984858  AT&T
# 3     36410662  AT&T
# ...

# %%
data_6 = yf.download('MSFT', start_date, end_date)
data_6.reset_index(inplace = True)
data_6['stock'] = 'MSFT'
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_6
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2013-01-02   27.250000   27.730000   27.150000   27.620001   22.717783
# 1    2013-01-03   27.629999   27.650000   27.160000   27.250000   22.413458
# 2    2013-01-04   27.270000   27.340000   26.730000   26.740000   21.993975
# 3    2013-01-07   26.770000   26.879999   26.639999   26.690001   21.952847
# 4    2013-01-08   26.750000   26.790001   26.459999   26.549999   21.837692
# ...         ...         ...         ...         ...         ...         ...
# 2579 2023-03-31  283.730011  289.269989  283.000000  288.299988  288.299988
# 2580 2023-04-03  286.519989  288.269989  283.950012  287.230011  287.230011
# 2581 2023-04-04  287.230011  290.450012  285.670013  287.179993  287.179993
# 2582 2023-04-05  285.850006  287.149994  282.920013  284.339996  284.339996
# 2583 2023-04-06  283.209991  292.079987  282.029999  291.600006  291.600006
#
#         Volume stock
# 0     52899300  MSFT
# ...

# %%
df3 = pd.concat([data_1,data_2,data_3,data_4,data_5,data_6])
df3
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2013-01-02   12.804000   12.905000   12.663000   12.865500   12.865500
# 1    2013-01-03   12.863500   13.044000   12.818500   12.924000   12.924000
# 2    2013-01-04   12.879000   12.990000   12.832500   12.957500   12.957500
# 3    2013-01-07   13.148500   13.486500   13.133500   13.423000   13.423000
# 4    2013-01-08   13.353500   13.449000   13.178500   13.319000   13.319000
# ...         ...         ...         ...         ...         ...         ...
# 2579 2023-03-31  283.730011  289.269989  283.000000  288.299988  288.299988
# 2580 2023-04-03  286.519989  288.269989  283.950012  287.230011  287.230011
# 2581 2023-04-04  287.230011  290.450012  285.670013  287.179993  287.179993
# 2582 2023-04-05  285.850006  287.149994  282.920013  284.339996  284.339996
# 2583 2023-04-06  283.209991  292.079987  282.029999  291.600006  291.600006
#
#         Volume   stock
# 0     65420000  Amazon
# ...

# %%
stocks = ['AMZN','CVX','IBM','ARCC','T','MSFT']

dataset = pd.DataFrame()
for i in stocks:
  data = yf.download(i, start_date, end_date)
  data.reset_index(inplace = True)
  data['stock'] = i
  dataset = pd.concat([dataset,data])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
dataset
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2013-01-02   12.804000   12.905000   12.663000   12.865500   12.865500
# 1    2013-01-03   12.863500   13.044000   12.818500   12.924000   12.924000
# 2    2013-01-04   12.879000   12.990000   12.832500   12.957500   12.957500
# 3    2013-01-07   13.148500   13.486500   13.133500   13.423000   13.423000
# 4    2013-01-08   13.353500   13.449000   13.178500   13.319000   13.319000
# ...         ...         ...         ...         ...         ...         ...
# 2579 2023-03-31  283.730011  289.269989  283.000000  288.299988  288.299988
# 2580 2023-04-03  286.519989  288.269989  283.950012  287.230011  287.230011
# 2581 2023-04-04  287.230011  290.450012  285.670013  287.179993  287.179993
# 2582 2023-04-05  285.850006  287.149994  282.920013  284.339996  284.339996
# 2583 2023-04-06  283.209991  292.079987  282.029999  291.600006  291.600006
#
#         Volume stock
# 0     65420000  AMZN
# ...

# %%
df3.to_csv('stock_prices.csv')

# %%
df3.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# stock        0
# dtype: int64

# %%
df3.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  15504.000000  15504.000000  15504.000000  15504.000000  15504.000000
# mean      83.675889     84.444691     82.876105     83.679235     71.903332
# std       66.516957     67.163013     65.852578     66.527425     62.745838
# min        8.840000      9.730000      7.900000      8.080000      6.067052
# 25%       22.498112     22.694487     22.280968     22.475453     17.070858
# 50%       75.955002     76.855000     74.811749     75.779999     66.356758
# 75%      128.210564    129.156952    127.160614    128.250000    107.859076
# max      344.619995    349.670013    342.200012    343.109985    339.075562
#
#              Volume
# count  1.550400e+04
# mean   2.813325e+07
# std    3.425995e+07
# min    4.014000e+05
# 25%    4.157589e+06
# 50%    1.623234e+07
# 75%    4.110795e+07
# max    4.771220e+08

# %%
df3.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# stock                object
# dtype: object

# %% [markdown]
# ### Closing Price
#
# Closing price refers to the last price at which a securities is traded on a regular trading day. The closing price of a stock is commonly used as a benchmark by investors to evaluate performance over time.

# %%
# Let's see a historical view of the closing price
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 3, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {stocks[i - 1]}")
    
plt.tight_layout()

# %% [markdown]
# ### Volume of Sales
# Trading volume refers to the total value of purchases and sales of a security or asset over a given time frame, most commonly a day. A stock's trading volume, for instance, would be the total number of shares bought and sold between the market's open and close times for that day. Technical traders rely heavily on information such as trading volume and variations in trading volume over time.

# %%
# Now let's plot the total volume of stock being traded each day
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(3, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {stocks[i - 1]}")
    
plt.tight_layout()

# %% [markdown]
# Let's compute the stock's moving average now that we've viewed charts of the daily closing price and trading volume.

# %% [markdown]
# ### 2. What was the moving average of the various stocks?
# The moving average (MA) is a basic technique used in technical analysis that averages out price changes over time to provide a smoother picture. The average is calculated over a time frame selected by the trader; this can be 10 days, 20 days, 50 days, or any other interval of time the trader deems appropriate.

# %%
ma_day = [10, 20, 50]

for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        

fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(20)

AMZN[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,0])
axes[0,0].set_title('Amazon')

CVX[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,1])
axes[0,1].set_title('Chevron')

IBM[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,0])
axes[1,0].set_title('IBM')

MSFT[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,1])
axes[1,1].set_title('Microsoft')

fig.tight_layout()

# %%
ma_day = [10, 20, 50]

for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        

fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(20)

ARCC[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,0])
axes[0,0].set_title('Ares Capital')

T[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,1])
axes[0,1].set_title('AT&T')
fig.tight_layout()

# %% [markdown]
# We see in the graph that the best values to measure the moving average are 10 and 20 days because we still capture trends in the data without noise.

# %% [markdown]
# ### 3. What was the daily return of the stock on average?
# Let's go into more detail now that we've established a foundational level of examination. Here, we'll assess the potential dangers associated with this stock. To do so, we need to focus on the stock's daily fluctuations rather than just its total value.

# %%
# We'll use pct_change to find the percent change for each day
for company in company_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

# Then we'll plot the daily return percentage
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

AMZN['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title('Amazon')

CVX['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('Chevron')

IBM['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('IBM')

MSFT['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('Microsoft')

fig.tight_layout()

# %%
# We'll use pct_change to find the percent change for each day
for company in company_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

# Then we'll plot the daily return percentage
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

ARCC['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title('Ares Capital')

T['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('AT&T')

fig.tight_layout()

# %% [markdown]
# Great, now let's get an overall look at the average daily return using a histogram. We'll use seaborn to create both a histogram and kde plot on the same figure.

# %%
plt.figure(figsize=(12, 9))

for i, company in enumerate(company_list, 1):
    plt.subplot(3, 2, i)
    company['Daily Return'].hist(bins=50)
    plt.xlabel('Daily Return')
    plt.ylabel('Counts')
    plt.title(f'{company_name[i - 1]}')
    
plt.tight_layout()

# %% [markdown]
# ## 4. Expected Return and Risk percentage involved in the individual stocks till date

# %%
# Download the stock data for the tickers
stock_data = yf.download(stocks, start="2015-01-01", end=str(dt.today()))['Adj Close']

# Calculate daily returns
returns = stock_data.pct_change()

# Calculate mean daily return and daily standard deviation of returns
mean_returns = returns.mean()
std_returns = returns.std()

# Define the number of simulations
num_simulations = 1000

# Set the random seed for reproducibility
np.random.seed(42)

# Create an empty array to store simulation results
results = np.zeros((num_simulations, 2))

# Simulate portfolio returns for each ticker
for i in range(num_simulations):
    # Generate random weights for the stocks
    weights = np.random.random(len(stocks))
    weights /= np.sum(weights)
    # Calculate the portfolio return and standard deviation
    portfolio_return = np.sum(mean_returns * weights)
    portfolio_std = np.sqrt(np.dot(weights.T, np.dot(returns[stocks].cov(), weights)))
    results[i,:] = [portfolio_return, portfolio_std]

# Convert results to a DataFrame
sim_df = pd.DataFrame(results, columns=['Expected Return', 'Risk'])

# Print the results
print(sim_df.head())
# Out:
# [*********************100%***********************]  6 of 6 completed
#    Expected Return      Risk
# 0         0.000585  0.013133
# 1         0.000421  0.013451
# 2         0.000755  0.013849
# 3         0.000683  0.012575
# 4         0.000720  0.012655

# %% [markdown]
# ### 5. What was the correlation between different stocks closing prices?
# A correlation statistic has a value between -1.0 and +1.0 if it is to accurately reflect the degree to which changes in each variable are affected by changes in the other. Correlation is a measure of association, but it doesn't tell us whether x causes y or whether y causes x, or whether the two are related because of a third factor[1].
#
# Let's say we have a list of stocks and would like to compare their returns. Now, let's create a DataFrame including all the ['Close'] columns from the stock dataframes.

# %%
# Grab all the closing prices for the tech stock list into one DataFrame

closing_df = pdr.get_data_yahoo(stocks, start=start_date, end=end_date)['Adj Close']

# Make a new tech returns DataFrame
tech_rets = closing_df.pct_change()
tech_rets.head()
# Out:
# [*********************100%***********************]  6 of 6 completed
#                 AMZN      ARCC       CVX       IBM      MSFT         T
# Date
# 2013-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2013-01-03  0.004547  0.003948 -0.004258 -0.005500 -0.013396  0.000571
# 2013-01-04  0.002592  0.002247  0.005276 -0.006555 -0.018716  0.005997
# 2013-01-07  0.035925 -0.003363 -0.006787 -0.004382 -0.001870  0.004542
# 2013-01-08 -0.007748 -0.000562 -0.004465 -0.001398 -0.005245 -0.012766

# %% [markdown]
# Now we may see how closely two equities are related by contrasting their daily percentage returns. Let's start with a self-contrast of a sock.

# %%
# Comparing Amazon to itself should show a perfectly linear relationship
sns.jointplot(x='AMZN', y='AMZN', data=tech_rets, kind='scatter', color='seagreen')

# %%
# We'll use joinplot to compare the daily returns of Google and Microsoft
sns.jointplot(x='AMZN', y='CVX', data=tech_rets, kind='scatter')

# %% [markdown]
# Now we can see that a linear relationship between the daily return values of two stocks should take place if they are perfectly (and positively) connected with one another.
#
# Because of the power of Seaborn and pandas, we can quickly and easily run this comparative study on any pair of stocks from our technological stock ticker. Automatically generating this plot is possible with the help of sns.pairplot().

# %%
# We can simply call pairplot on our DataFrame for an automatic visual analysis 
# of all the comparisons

sns.pairplot(tech_rets, kind='reg')

# %% [markdown]
# All the correlations between stocks' daily results are displayed above. The daily sales figures for AT&T and Amazon have an intriguing link. That specific comparison might be worth looking into.
#
# While it's great that all we have to do to generate a pair-plot is call sns.pairplot(), we can also utilise sns.
#
# PairGrid() allows the user complete freedom over the layout of the diagram, down to the type of plots displayed in the diagonal, upper triangle, and lower triangle. See what can be accomplished by harnessing seaborn's full potential in the example below.

# %%
# Set up our figure by naming it returns_fig, call PairPLot on the DataFrame
return_fig = sns.PairGrid(tech_rets.dropna())

# Using map_upper we can specify what the upper triangle will look like.
return_fig.map_upper(plt.scatter, color='purple')

# We can also define the lower triangle in the figure, inclufing the plot type (kde) 
# or the color map (BluePurple)
return_fig.map_lower(sns.kdeplot, cmap='cool_d')

# Finally we'll define the diagonal as a series of histogram plots of the daily return
return_fig.map_diag(plt.hist, bins=30)

# %%
# Set up our figure by naming it returns_fig, call PairPLot on the DataFrame
returns_fig = sns.PairGrid(closing_df)

# Using map_upper we can specify what the upper triangle will look like.
returns_fig.map_upper(plt.scatter,color='purple')

# We can also define the lower triangle in the figure, inclufing the plot type (kde) or the color map (BluePurple)
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')

# Finally we'll define the diagonal as a series of histogram plots of the daily return
returns_fig.map_diag(plt.hist,bins=30)

# %% [markdown]
# Finally, we could also do a correlation plot, to get actual numerical values for the correlation between the stocks' daily return values. By comparing the closing prices, we see an interesting relationship between Microsoft and Apple.

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
sns.heatmap(tech_rets.corr(), annot=True, cmap='summer')
plt.title('Correlation of stock return')

plt.subplot(2, 2, 2)
sns.heatmap(closing_df.corr(), annot=True, cmap='summer')
plt.title('Correlation of stock closing price')
# Out:
# Text(0.5, 1.0, 'Correlation of stock closing price')

# %% [markdown]
# Indeed, the numbers and the chart confirm what we saw intuitively in the PairPlot: daily stock returns for Microsoft and Amazon are most correlated with one another. What's more, it's fascinating to note the strong positive correlation between all the technology companies.

# %% [markdown]
# ### 6. How much value do we put at risk by investing in a particular stock?
# There are many ways we can quantify risk, one of the most basic ways using the information we've gathered on daily percentage returns is by comparing the expected return with the standard deviation of the daily returns.

# %%
rets = tech_rets.dropna()

area = np.pi * 20

plt.figure(figsize=(10, 8))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))

# %% [markdown]
# # 7. Prediction of Closing Price

# %% [markdown]
# ##Amazon stock:

# %%
# Get the stock quote
df = pdr.get_data_yahoo('AMZN', start='2013-01-01', end=datetime.now())
# Show teh data
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-01-02   12.804000   12.905000   12.663000   12.865500   12.865500
# 2013-01-03   12.863500   13.044000   12.818500   12.924000   12.924000
# 2013-01-04   12.879000   12.990000   12.832500   12.957500   12.957500
# 2013-01-07   13.148500   13.486500   13.133500   13.423000   13.423000
# 2013-01-08   13.353500   13.449000   13.178500   13.319000   13.319000
# ...                ...         ...         ...         ...         ...
# 2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
# 2023-04-06  100.750000  102.379997   99.800003  102.059998  102.059998
# 2023-04-10  100.959999  101.859802   99.570000  101.760002  101.760002
#
#               Volume
# Date
# ...

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Create a new dataframe with only the 'Close column 
data = df.filter(['Close'])
# Convert the dataframe to a numpy array
dataset = data.values
# Get the number of rows to train the model on
training_data_len = int(np.ceil( len(dataset) * .95 ))

training_data_len
# Out:
# 2456

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.00260682],
#        [0.00294271],
#        [0.00313507],
#        ...,
#        [0.50923869],
#        [0.51475089],
#        [0.51302835]])

# %%
# Create the training data set 
# Create the scaled training data set
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# x_train.shape
# Out:
# [array([0.00260682, 0.00294271, 0.00313507, 0.00580791, 0.00521076,
#        0.00520214, 0.00491218, 0.00565862, 0.0070338 , 0.00679552,
#        0.00594284, 0.00638784, 0.00685868, 0.00630458, 0.00570743,
#        0.00724338, 0.01026648, 0.00798408, 0.00347958, 0.00704241,
#        0.00495811, 0.00481457, 0.00337335, 0.00535717, 0.00401645,
#        0.00344513, 0.00393893, 0.00257811, 0.00300588, 0.00609788,
#        0.00603184, 0.00484041, 0.00617826, 0.00521937, 0.00508443,
#        0.00493515, 0.00334177, 0.00319536, 0.00431215, 0.00460499,
#        0.00502701, 0.0071429 , 0.00785489, 0.00733812, 0.00736396,
#        0.00745296, 0.00660603, 0.00743573, 0.00771422, 0.00502701,
#        0.00390161, 0.00277333, 0.00234843, 0.0025982 , 0.00148141,
#        0.00273313, 0.00223646, 0.0034681 , 0.0049007 , 0.00524234])]
# [0.003841315629562053]
#
# [array([0.00260682, 0.00294271, 0.00313507, 0.00580791, 0.00521076,
#        0.00520214, 0.00491218, 0.00565862, 0.0070338 , 0.00679552,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# 2396/2396 [==============================] - 96s 39ms/step - loss: 0.0022

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data = scaled_data[training_data_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    
# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# 5/5 [==============================] - 1s 33ms/step
# 5.0827757023273294

# %%
# Plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# <ipython-input-46-0cdd5e68a3a9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
# Show the valid and predicted prices
valid
# Out:
#                  Close  Predictions
# Date
# 2022-10-04  121.089996   117.064468
# 2022-10-05  120.949997   117.955963
# 2022-10-06  120.300003   119.156624
# 2022-10-07  114.559998   120.225868
# 2022-10-10  113.669998   120.166367
# ...                ...          ...
# 2023-04-03  102.410004   101.667526
# 2023-04-04  103.949997   102.467018
# 2023-04-05  101.099998   103.337173
# 2023-04-06  102.059998   103.671509
# 2023-04-10  101.760002   103.843369
#
# [129 rows x 2 columns]

# %% [markdown]
# ## Microsoft:

# %%
# Get the stock quote
df = pdr.get_data_yahoo('MSFT', start='2013-01-01', end=datetime.now())
# Show teh data
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-01-02   27.250000   27.730000   27.150000   27.620001   22.717785
# 2013-01-03   27.629999   27.650000   27.160000   27.250000   22.413456
# 2013-01-04   27.270000   27.340000   26.730000   26.740000   21.993975
# 2013-01-07   26.770000   26.879999   26.639999   26.690001   21.952845
# 2013-01-08   26.750000   26.790001   26.459999   26.549999   21.837694
# ...                ...         ...         ...         ...         ...
# 2023-04-03  286.519989  288.269989  283.950012  287.230011  287.230011
# 2023-04-04  287.230011  290.450012  285.670013  287.179993  287.179993
# 2023-04-05  285.850006  287.149994  282.920013  284.339996  284.339996
# 2023-04-06  283.209991  292.079987  282.029999  291.600006  291.600006
# 2023-04-10  289.208008  289.208008  284.720001  288.509399  288.509399
#
#               Volume
# Date
# ...

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
# Create a new dataframe with only the 'Close column 
data = df.filter(['Close'])
# Convert the dataframe to a numpy array
dataset = data.values
# Get the number of rows to train the model on
training_data_len = int(np.ceil( len(dataset) * .95 ))

training_data_len
# Out:
# 2456

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.00366336],
#        [0.00249487],
#        [0.00088426],
#        ...,
#        [0.81440078],
#        [0.83732834],
#        [0.82756801]])

# %%
# Create the training data set 
# Create the scaled training data set
train_data = scaled_data[0:int(training_data_len), :]
# Split the data into x_train and y_train data sets
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Convert the x_train and y_train to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# x_train.shape
# Out:
# [array([0.00366336, 0.00249487, 0.00088426, 0.00072636, 0.00028423,
#        0.00075794, 0.        , 0.00116849, 0.00135797, 0.00236855,
#        0.00183168, 0.00249487, 0.00249487, 0.00217906, 0.00363178,
#        0.00369493, 0.00448445, 0.00457919, 0.004895  , 0.00438971,
#        0.00312649, 0.00464235, 0.0030949 , 0.00328439, 0.0027791 ,
#        0.00258962, 0.00344229, 0.00442129, 0.00448445, 0.00495816,
#        0.00498974, 0.004895  , 0.00502132, 0.00445287, 0.00325281,
#        0.00410548, 0.00287384, 0.00287384, 0.00426338, 0.0042318 ,
#        0.00470552, 0.00533712, 0.00596874, 0.00514764, 0.00530554,
#        0.00486342, 0.00445287, 0.00457919, 0.00461077, 0.00530554,
#        0.00498974, 0.00517922, 0.00543187, 0.005874  , 0.00521081,
#        0.00565293, 0.00536871, 0.00536871, 0.0060319 , 0.00678984])]
# [0.006789836157028634]
#
# [array([0.00366336, 0.00249487, 0.00088426, 0.00072636, 0.00028423,
#        0.00075794, 0.        , 0.00116849, 0.00135797, 0.00236855,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Build the LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# 2396/2396 [==============================] - 99s 40ms/step - loss: 0.0013

# %%
# Create the testing data set
# Create a new array containing scaled values from index 1543 to 2002 
test_data = scaled_data[training_data_len - 60: , :]
# Create the data sets x_test and y_test
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    
# Convert the data to a numpy array
x_test = np.array(x_test)

# Reshape the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Get the models predicted price values 
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# 5/5 [==============================] - 1s 29ms/step
# 8.547051970483736

# %%
# Plot the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# <ipython-input-55-0cdd5e68a3a9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
# Show the valid and predicted prices
valid
# Out:
#                  Close  Predictions
# Date
# 2022-10-04  248.880005   242.988846
# 2022-10-05  249.199997   244.409225
# 2022-10-06  246.789993   246.379654
# 2022-10-07  234.240005   248.058197
# 2022-10-10  229.250000   247.730850
# ...                ...          ...
# 2023-04-03  287.230011   282.760132
# 2023-04-04  287.179993   284.535126
# 2023-04-05  284.339996   286.042694
# 2023-04-06  291.600006   286.836090
# 2023-04-10  288.509399   288.148865
#
# [129 rows x 2 columns]
